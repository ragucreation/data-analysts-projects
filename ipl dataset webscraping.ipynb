# %%
import pandas as pd
import numpy as ny
import seaborn as sns
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
import requests
import re

# %%
URL="https://www.india.com/ipl/squads/"
req=requests.get(URL)

# %%
req
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(req.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="ipl-2024" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://www.india.com/favicon.ico" rel="icon" type="image/icon"/>
# <!--fonts -->
# <!-- Hindi -->
# <!-- English font -->
# <link as="font" crossorigin="" href="https://static.india.com/wp-content/themes/icom/fonts/Poppins-latin-regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://static.india.com/wp-content/themes/icom/fonts/Poppins-latin-Bold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://static.india.com/wp-content/themes/icom/fonts/Poppins-600.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
column=['Image_link','Name','Position','Age','OVA','POT','Team','Duration','Value','Wage','Total_stats','Hits']

# %%
for i in soup.findAll('div'):
  print(i)
# Out:
# <div class="container-full">
# <div class="sso-content">
# <div class="others-sites">
# <ul>
# <li><a href="https://www.wionews.com/" target="_blank">WION</a></li>
# <li><a href="https://www.thehealthsite.com/" target="_blank">The Health Site</a></li>
# <li><a href="https://www.bollywoodlife.com/" target="_blank">Bollywood Life</a></li>
# <li><a href="https://www.cricketcountry.com/" target="_blank">Cricket Country</a></li>
# <li><a href="https://www.zeebiz.com/" target="_blank">Zee Business</a></li>
# <li><a href="https://www.techlusive.in/" target="_blank">Techlusive</a></li>
# </ul>
# </div>
# <!--location starts-->
# <!--zee language starts-->
# <div class="new-head-line">
# <div class="zee-language">
# <ul>
# <li class="first">ZEE [</li>
# <li><a href="https://zeenews.india.com/hindi" target="_blank">हिन्दी</a></li>
# <li><a href="https://zeenews.india.com/" target="_blank">ENGLISH</a></li>
# <li><a href="https://zeenews.india.com/marathi/" target="_blank">मराठी</a></li>
# ...

# %%
arr[1]
# Out:
# '<a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>'

# %%
arr=[ ]
for i in soup.findAll('div'):
  arr.append(str(i))

# %%
arr[27]
# Out:
# '<div class="two-cols-aside">\n<!--lhs starts-->\n<section class="lhs-col">\n<div class="squad-details">\n<h1 class="heading">Chennai Full Squad</h1>\n<div class="squad-team-name chennai">\n<div class="name"><i class="team-icon"><img alt="" height="20" src="https://www.india.com/ipl/img/ipl-team-default-icon.svg" width="18"/></i> </div>\n<div class="three-cols">\n<div class="col">\n<ul>\n<li class="captain">\r\n                                            Ms Dhoni                                          </li>\n<li class="">\r\n                                            Devon Conway                                          </li>\n<li class="">\r\n                                            Ruturaj Gaikwad                                          </li>\n<li class="">\r\n                                            Ajinkya Rahane                                          </li>\n<li class="">\r\n                                            Shaik Rasheed                                     
# ...

# %%
re.sub('^<div>.*">|<div>|</div>|<.*>|\r|\n' ," ",str(arr[27]))
# Out:
# '                                                                   Ms Dhoni                                                                                           Devon Conway                                                                                           Ruturaj Gaikwad                                                                                           Ajinkya Rahane                                                                                           Shaik Rasheed                                                                                           Sameer Rizvi                                                                                           Avanish Rao Aravelly                                                                                           Ravindra Jadeja                                                                                           Mitchell Santner                                                                             
# ...

# %%
CHENNAI  =[]
MUMBAI   =[]
KOLKATA  =[]
BANGALORE =[]
DELHI     =[]


count=0

for i in soup.findAll('div'):
  i=re.sub('^<div>.*">|<div>|</div>|<.*>|\r|\n' ," ",str(arr[27]))

  if count==0:
    CHENNAI.append(i)
    count +=1
  elif count ==1:
    MUMBAI .append(i)
    count +=1
  elif count ==2:
   KOLKATA.append(i)
   count +=1
  elif count ==3:
   BANGALORE.append(i)
   count +=1
else:
    count=0
    DELHI.append(i)
    count+=1

# %%
CHENNAI
# Out:
# ['                                                                   Ms Dhoni                                                                                           Devon Conway                                                                                           Ruturaj Gaikwad                                                                                           Ajinkya Rahane                                                                                           Shaik Rasheed                                                                                           Sameer Rizvi                                                                                           Avanish Rao Aravelly                                                                                           Ravindra Jadeja                                                                                           Mitchell Santner                                                                            
# ...

# %%
ipl=pd.DataFrame({'CHENNAI ':CHENNAI[:1372],'MUMBAI':MUMBAI[:1372],'KOLKATA':KOLKATA[:1372],'BANGALORE':BANGALORE[:1372]})

# %%
ipl
# Out:
#                                             CHENNAI   \
# 0                                                ...
#
#                                               MUMBAI  \
# 0                                                ...
#
#                                              KOLKATA  \
# 0                                                ...
#
#                                            BANGALORE
# 0                                                ...
